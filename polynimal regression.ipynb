# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"D:\Jupyter\RESUME PROJECTS\CARS RESALE\car.xlsx")
df
# Out:
#        brand  model  transmission  age  fuel      price  mileage     power  \
# 0         18    244             1    4     1  1231000.0    19.01  4.496471
# 1         10    263             1    6     4   786000.0    19.01  4.496471
# 2         31    123             1    2     1  1489000.0    19.01  4.496471
# 3          9     55             0    1     4  1227000.0    19.01  4.496471
# 4          8     82             1    3     1   887000.0    19.01  4.496471
# ...      ...    ...           ...  ...   ...        ...      ...       ...
# 32009      5    199             1    6     4   292000.0    19.01  4.496471
# 32010     32    295             1    6     4   534000.0    19.01  4.496471
# 32011     33     25             1    8     4   424000.0    19.01  4.496471
# 32012     10    120             0    5     4   685000.0    19.01  4.496471
# 32013     31    247             1    2     4   392000.0    19.01  4.496471
#
#        seats
# 0          5
# 1          5
# 2          5
# 3          5
# 4          5
# ...      ...
# 32009      5
# 32010      5
# 32011      5
# 32012      5
# 32013      5
#
# [32014 rows x 9 columns]

# %%
# Separate the features (X) and target variable (y)
X = df.drop('price', axis=1)
y = df['price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=32)

# %%
 #4
from sklearn.preprocessing import PolynomialFeatures
polynomial_converter = PolynomialFeatures(degree=2,include_bias=False)
X_train_poly = pd.DataFrame(polynomial_converter.fit_transform(X_train))
X_test_poly = pd.DataFrame(polynomial_converter.fit_transform(X_test))

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_poly,y_train)

print(model.intercept_)
print(model.coef_)


from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

#6
ypred_train = model.predict(X_train_poly)
ypred_test = model.predict(X_test_poly)
#7
print('trainr2:',r2_score(y_train,ypred_train))
print('cv:',cross_val_score(model,X_train_poly,y_train,cv=5,scoring='r2').mean())
print('Test r2:',r2_score(y_test, ypred_test))
# Out:
# 8845162.943580108
# [ 3.50060525e+04  1.00125326e+04  1.76938182e+06  2.81324514e+05
#   3.68532950e+04 -1.04521389e+05 -4.27191972e+06 -1.05299466e+06
#  -2.21583342e+02 -3.60489391e+01  6.80765085e+03 -1.81842016e+01
#  -8.57650117e+02 -3.41852417e+02 -1.94004236e+03 -1.94782765e+03
#  -4.22421322e+00 -1.42159665e+02 -7.01660290e+00 -6.60974894e+01
#  -3.96008981e+01 -9.12584019e+02 -5.56647825e+02  1.76938182e+06
#   3.20292610e+04  3.73664409e+04 -1.81405829e+04 -9.01174090e+05
#   5.95075835e+04  4.82816379e+02  4.78415641e+03  1.35811193e+03
#  -1.04809978e+05  1.26947629e+04 -4.31600831e+04  9.80622960e+03
#  -3.07110828e+04  7.81268241e+03  1.56173871e+03 -8.14849072e+03
#   1.41590555e+04  7.68583648e+05  3.95248112e+04  4.69277303e+04]
# trainr2: 0.7583724611475917
# cv: 0.7557543449300718
# Test r2: 0.7308213321438874

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_converter = PolynomialFeatures(degree=3,include_bias=False)
X_train_poly = pd.DataFrame(polynomial_converter.fit_transform(X_train))
X_test_poly = pd.DataFrame(polynomial_converter.fit_transform(X_test))

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_poly,y_train)

print(model.intercept_)
print(model.coef_)


from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score