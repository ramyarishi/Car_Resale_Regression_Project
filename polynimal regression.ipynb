# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"D:\Jupyter\RESUME PROJECTS\CARS RESALE\car.xlsx")
df
# Out:
#        brand  model  transmission  fuel      price     power  seats
# 0         19    211             1     0   175000.0  4.080246      5
# 1         10     58             1     1  1250000.0  4.845761      5
# 2          9    111             1     4   450000.0  4.496471      5
# 3         19     76             1     1   600000.0  4.497139      7
# 4          1      9             0     1  1774000.0  4.954418      5
# ...      ...    ...           ...   ...        ...       ...    ...
# 21084     10    104             1     4   250000.0  4.234831      5
# 21085     19     76             1     4   925000.0  4.522875      7
# 21086     29    157             1     1   425000.0  4.649378      5
# 21087     18    232             1     1  1225000.0  4.948760      7
# 21088      9     44             0     4  1200000.0  4.775756      5
#
# [21089 rows x 7 columns]

# %%
# Separate the features (X) and target variable (y)
X = df.drop('price', axis=1)
y = df['price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=53)

# %%
 #4
from sklearn.preprocessing import PolynomialFeatures
polynomial_converter = PolynomialFeatures(degree=2,include_bias=False)
X_train_poly = pd.DataFrame(polynomial_converter.fit_transform(X_train))
X_test_poly = pd.DataFrame(polynomial_converter.fit_transform(X_test))

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_poly,y_train)

print(model.intercept_)
print(model.coef_)


from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

#6
ypred_train = model.predict(X_train_poly)
ypred_test = model.predict(X_test_poly)
#7
print('trainr2:',r2_score(y_train,ypred_train))
print('cv:',cross_val_score(model,X_train_poly,y_train,cv=5,scoring='r2').mean())
print('Test r2:',r2_score(y_test, ypred_test))
# Out:
# 7092225.425497369
# [ 6.58717605e+04  1.15421599e+04  1.32184047e+06  5.20405595e+05
#  -4.24161861e+06 -6.77052228e+05 -9.99038472e+02 -6.84663247e+01
#   6.58028480e+03  2.52153057e+02 -6.07247037e+03  2.81619157e+02
#  -1.30752751e+01 -4.71345054e+02  6.93781144e+01 -5.37438481e+02
#  -9.51697005e+02  1.32184047e+06  3.31454434e+04 -6.93008503e+05
#   3.13486962e+04  9.95513042e+03 -1.45324037e+05 -6.23303997e+02
#   6.58285713e+05  7.51299147e+04  3.31603207e+04]
# trainr2: 0.6707523559095243
# cv: 0.6672125609027854
# Test r2: 0.6447291141889531

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_converter = PolynomialFeatures(degree=3,include_bias=False)
X_train_poly = pd.DataFrame(polynomial_converter.fit_transform(X_train))
X_test_poly = pd.DataFrame(polynomial_converter.fit_transform(X_test))

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_poly,y_train)

print(model.intercept_)
print(model.coef_)


from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

#6
ypred_train = model.predict(X_train_poly)
ypred_test = model.predict(X_test_poly)
#7
print('trainr2:',r2_score(y_train,ypred_train))
print('cv:',cross_val_score(model,X_train_poly,y_train,cv=5,scoring='r2').mean())
print('Test r2:',r2_score(y_test, ypred_test))
# Out:
# 40138143.389040925
# [ 5.11515910e+05 -8.19375893e+04 -7.89576023e+06 -3.60393110e+06
#  -3.19827620e+07  9.50082013e+06  4.35381082e+03  8.84978590e+02
#  -5.58444115e+04  7.57031733e+03 -7.28737416e+04 -1.46184987e+05
#   8.69855153e+01  1.28609764e+03 -1.92678689e+03  9.74158265e+03
#   1.61140034e+04 -7.89576334e+06 -3.80809386e+05  5.45392479e+06
#   2.09110590e+05 -5.82916003e+05  2.65083447e+06 -2.24820348e+05
#   6.81969052e+06 -2.65127349e+06 -4.83915231e+05 -5.91844519e+01
#   6.82239034e-01 -1.96247893e+02  3.87062280e+02 -9.82436700e+02
#   3.47258869e+02  3.46112998e-01  5.53822057e+00 -5.41854810e+01
#  -8.30340265e+01 -1.03805386e+02 -5.58444648e+04 -7.20424431e+02
#   1.54490302e+04  1.02376405e+04 -3.44920448e+03 -9.44495482e+02
#   1.38598422e+03 -2.35240350e+03  2.31269625e+04  2.36136958e+03
#   8.13121474e-02 -6.34076414e+00  9.36323117e-01 -3.65910606e+01
#   7.71008010e+00  1.28611039e+03  1.60188558e+02 -5.96577681e+02
#   1.85546440e+02 -1.21094644e+02  4.10584661e+02  2.47846517e+02
#   7.60205598e+02 -1.55921141e+03 -7.72682861e+02 -7.89576334e+06
#  -3.80809383e+05  5.45392479e+06  2.09110590e+05  2.17703339e+05
#  -3.68792798e+04 -2.81329321e+04 -1.14327768e+06 -2.07010178e+05
#   3.74030596e+04  3.72980917e+04  2.87074863e+04  1.69263348e+04
#  -3.08616621e+05 -1.04405230e+04  1.27160686e+04 -3.77485956e+05
#   1.00968309e+05  1.30993239e+05 -6.32978162e+03]
# trainr2: 0.6929347431379298
# cv: 0.6840121985011762
# Test r2: 0.6749552560745504

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_converter = PolynomialFeatures(degree=4,include_bias=False)
X_train_poly = pd.DataFrame(polynomial_converter.fit_transform(X_train))
X_test_poly = pd.DataFrame(polynomial_converter.fit_transform(X_test))

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_poly,y_train)

print(model.intercept_)
print(model.coef_)


from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

#6
ypred_train = model.predict(X_train_poly)
ypred_test = model.predict(X_test_poly)
#7
print('trainr2:',r2_score(y_train,ypred_train))
print('cv:',cross_val_score(model,X_train_poly,y_train,cv=5,scoring='r2').mean())
print('Test r2:',r2_score(y_test, ypred_test))
# Out:
# 1028831052.9426816
# [-2.57469614e+08 -7.38509808e+07 -1.40013980e+08 -5.06525452e+08
#   4.45414271e+08  5.85651688e+08 -4.59482404e+04  2.55806907e+04
#   8.65637889e+07  3.26470704e+08  1.28095041e+06 -2.48642768e+06
#   1.44027948e+03  2.49396715e+07  9.34015306e+07 -4.10750501e+05
#  -3.21026076e+05 -1.40014345e+08 -1.30158518e+08 -2.49249293e+08
#  -2.39603517e+08 -2.94464481e+08 -1.01542510e+09 -5.26197915e+08
#   6.78511394e+07  8.51324867e+07  1.26187332e+07 -2.55488317e+03
#  -1.52553414e+02  2.31258042e+04  9.01538330e+03  2.54413920e+03
#   2.89492095e+04  1.06791807e+01 -2.28007616e+03 -2.20115668e+02
#  -4.04893454e+03 -4.41996429e+03  8.65638499e+07 -1.63676387e+08
#  -1.76797687e+05  4.01699470e+05 -6.56883472e+07  1.81438521e+05
#   2.82290409e+05 -6.44698010e+05  5.70140381e+05  2.72070866e+04
#  -3.99557380e+00  8.61292153e+01 -6.17949161e+01  2.32113380e+02
#  -4.35466349e+02  2.49396638e+07 -4.67265711e+07 -2.76532608e+03
#  -3.48015781e+03 -1.86649555e+07 -2.03536514e+04  1.70471402e+04
